# %%
from wots_cookin.data import load_clean_data
from wots_cookin.dietary_req import dietary_tagging

# %%
df = load_clean_data(limit = 10)
df = dietary_tagging(df)
df
# Out:
# 8 rows containing NAs dropped...
# 6 rows containing empty ingredients dropped...
# Data loaded.
# Cleaning formatting...
# Returning list of 461 stopwords
# Removing stopwords...
# Order's up!
# Returning dataframe with Bag_Of_Ingredients
#       index                                              Title  \
# 0         0  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1         2                        Thanksgiving Mac and Cheese
# 2         3                 Italian Sausage and Bread Stuffing
# 3         8                            Instant Pot Lamb Haleem
# 4         9     Spiced Lentil and Caramelized Onion Baked Eggs
# ...     ...                                                ...
# 7735  13479  Chocolate Heart Layer Cake with Chocolate-Cinn...
# 7736  13480      Ginger-Pecan Roulade with Honey-Glazed Pecans
# 7737  13482                               Brownie Pudding Cake
# 7738  13483  Israeli Couscous with Roasted Butternut Squash...
# ...

# %%
diet = ['Nut free', 'Vegetarian']

# %%
x = df[df[dietary_requirements].max(axis=1) == 0]
x
# Out:
#       index                                              Title  \
# 0         0  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 2         3                 Italian Sausage and Bread Stuffing
# 3         8                            Instant Pot Lamb Haleem
# 6        11                      Spiral Ham in the Slow Cooker
# 7        12                    Butternut Squash and Apple Soup
# ...     ...                                                ...
# 7729  13471              Chestnut, Onion, and Currant Stuffing
# 7731  13473                                     Pistachio Cake
# 7737  13482                               Brownie Pudding Cake
# 7738  13483  Israeli Couscous with Roasted Butternut Squash...
# 7739  13486  Mexican Poblano, Spinach, and Black Bean "Lasa...
#
#                                             Ingredients  \
# 0     ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 2     ['1 (¾- to 1-pound) round Italian loaf, cut in...
# ...

# %%
x['comb'] = x[['Nut free', 'Vegetarian']].max(axis=1)
# Out:
# /var/folders/fk/rr4337sx7vsdr42182kf4y4r0000gn/T/ipykernel_36832/3974129659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['comb'] = x[['Nut free', 'Vegetarian']].max(axis=1)

# %%
x.comb.value_counts()
# Out:
# 1    4237
# Name: comb, dtype: int64
