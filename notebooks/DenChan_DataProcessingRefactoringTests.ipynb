# %% [markdown]
# ### Data Exploration of Recipes Dataset

# %%
# Imports
import sys
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import string
from nltk.tokenize import word_tokenize
import numpy as np
import os, sys
# %load_ext autoreload 
# %autoreload 2

# %%
parent_path = os.path.split(os.getcwd())[0]
if parent_path  not in sys.path:
    sys.path.append(parent_path)

# %%
# Imports from local module
from wots_cookin.data import load_data, load_full_stopwords, remove_formatting, load_clean_data

# %%
# # Load the custom stopwords and return a list
# def load_custom_stopwords():
#     custom_stopwords_df = pd.read_csv("custom_stopwords.csv")
#     custom_stopwords = list(custom_stopwords_df['custom_stopwords'])
#     return custom_stopwords

# %%
# def load_data(nrows = None):
#     # Load the raw csv file
#     file = "../raw_data/recipes.csv"
#     df = pd.read_csv(file, nrows=nrows)
#     df_len = df.shape[0]
#     # Drop any NAs
#     df.dropna(inplace = True)
#     # Calculating the length of 'Cleaned_Ingredients' columns to identify any empty ingredients column and then dropping them
#     print(f'{df_len - df.shape[0]} rows containing NAs dropped...')
#     df_len = df.shape[0]
#     df['clean_len'] = [len(i) for i in df["Cleaned_Ingredients"]]
#     df.drop(df[df['clean_len']<5].index, axis = 0, inplace= True)
#     print(f'{df_len - df.shape[0]} rows containing empty ingredients dropped...')
#     # Drop unnecessary columns
#     df.drop(columns =['Unnamed: 0', 'clean_len'], inplace = True)
#     print('Order up!')
#     return df

# %%
load_clean_data(1000)
# Out:
# 0 rows containing NAs dropped...
# 0 rows containing empty ingredients dropped...
# Data loaded.
# Cleaning formatting...
# Returning list of 461 stopwords
# Removing stopwords...
# Order's up!
# Returning dataframe with Bag_Of_Ingredients
#                                                  Title  \
# 0    Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                      Crispy Salt and Pepper Potatoes
# 2                          Thanksgiving Mac and Cheese
# 3                   Italian Sausage and Bread Stuffing
# 4                                         Newton's Law
# ..                                                 ...
# 995                              Winter of Our Content
# 996                                     Perfect Circle
# 997                                      All She Wrote
# 998                                 Mr. Tingles' Punch
# 999                        Sunday Stash Sweet Potatoes
#
#                                            Ingredients  \
# ...

# %%
# df = load_data(5000)
# Out:
# 1 rows containing NAs dropped...
# 0 rows containing empty ingredients dropped...
# Order up!

# %%
# df.reset_index(drop=True, inplace = True)

# %%
# df.iloc[4293: 4294]
# Out:
#                       Title  \
# 4293  Roasted Poultry Stock
#
#                                             Ingredients  \
# 4293  ['Turkey neck, back, if spatchcocked, and gibl...
#
#                                            Instructions  \
# 4293  Preheat oven to 450°. Divide turkey parts, oni...
#
#                           Image_Name  \
# 4293  roasted-poultry-stock-51255620
#
#                                     Cleaned_Ingredients
# 4293  ['Turkey neck, back, if spatchcocked, and gibl...

# %%
df
# Out:
#                                                   Title  \
# 0     Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                       Crispy Salt and Pepper Potatoes
# 2                           Thanksgiving Mac and Cheese
# 3                    Italian Sausage and Bread Stuffing
# 4                                          Newton's Law
# ...                                                 ...
# 4994                           Shrimp Pad Thai For Four
# 4995                      Hot and Crunchy Avocado Fries
# 4996                   Fontina Mac with Squash and Sage
# 4997                  Spicy Jalapeño Sweet Potato Fries
# 4998                                Red Velvet Mug Cake
#
#                                             Ingredients  \
# 0     ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1     ['2 large egg whites', '1 pound new potatoes (...
# 2     ['1 cup evaporated milk', '1 cup whole milk', ...
# 3     ['1 (¾- to 1-pound) round Italian loaf, cut in...
# ...

# %%
# load_clean_data(nrows = None):
#     df = load_data(nrows)
#     df['Bag_Of_Ingredients'] = df['Cleaned_Ingredients'].map(remove_formatting)
#     df['Bag_Of_Ingredients'] = remove_stopwords(df['Bag_Of_Ingredients'])
#     print('Returning dataframe with Bag_Of_Ingredients')
#     return df
# Out:
# 1 rows containing NAs dropped...
# 0 rows containing empty ingredients dropped...
# Order up!
# Data loaded
# Format removed
# Returning list of 461 stopwords
# Removing stopwords...
# Order's up!

# %%
df
# Out:
#                                                   Title  \
# 0     Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                       Crispy Salt and Pepper Potatoes
# 2                           Thanksgiving Mac and Cheese
# 3                    Italian Sausage and Bread Stuffing
# 4                                          Newton's Law
# ...                                                 ...
# 4994                           Shrimp Pad Thai For Four
# 4995                      Hot and Crunchy Avocado Fries
# 4996                   Fontina Mac with Squash and Sage
# 4997                  Spicy Jalapeño Sweet Potato Fries
# 4998                                Red Velvet Mug Cake
#
#                                             Ingredients  \
# 0     ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1     ['2 large egg whites', '1 pound new potatoes (...
# 2     ['1 cup evaporated milk', '1 cup whole milk', ...
# 3     ['1 (¾- to 1-pound) round Italian loaf, cut in...
# ...

# %%
# from nltk.tokenize import word_tokenize

# def remove_stopwords(ingredient_list):
#     # Loading full stopwords list from regular and custom stopwords
#     full_stopwords = load_full_stopwords()
    
#     # Removing the stopwords to get bag of ingredients
#     print('Removing stopwords...')
#     for i in range(0, len(ingredient_list)):
#         ingredient_list[i] = ingredient_list[i].lower()
#         word_tokens = word_tokenize(ingredient_list[i])
#         ingredient_list[i] = [w for w in word_tokens if not w in full_stopwords]
#     print("Order's up!")
#     return ingredient_list

# %%
# df['Cleaned_Ingredients'][0] = df['Cleaned_Ingredients'][0].lower()

# %%
# df['Cleaned_Ingredients'][0]
# Out:
# '[\'1 (3½–4-lb.) whole chicken\', \'2¾ tsp. kosher salt, divided, plus more\', \'2 small acorn squash (about 3 lb. total)\', \'2 tbsp. finely chopped sage\', \'1 tbsp. finely chopped rosemary\', \'6 tbsp. unsalted butter, melted, plus 3 tbsp. room temperature\', \'¼ tsp. ground allspice\', \'pinch of crushed red pepper flakes\', \'freshly ground black pepper\', \'⅓ loaf good-quality sturdy white bread, torn into 1" pieces (about 2½ cups)\', \'2 medium apples (such as gala or pink lady; about 14 oz. total), cored, cut into 1" pieces\', \'2 tbsp. extra-virgin olive oil\', \'½ small red onion, thinly sliced\', \'3 tbsp. apple cider vinegar\', \'1 tbsp. white miso\', \'¼ cup all-purpose flour\', \'2 tbsp. unsalted butter, room temperature\', \'¼ cup dry white wine\', \'2 cups unsalted chicken broth\', \'2 tsp. white miso\', \'kosher salt\', \'freshly ground pepper\']'

# %%
df['Bag_Of_Ingredients'] = remove_stopwords(df['Bag_Of_Ingredients'])
# Out:
# Returning list of 461 stopwords
# Removing stopwords...
# Order's up!

# %%
df
# Out:
#                                                   Title  \
# 0     Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                       Crispy Salt and Pepper Potatoes
# 2                           Thanksgiving Mac and Cheese
# 3                    Italian Sausage and Bread Stuffing
# 4                                          Newton's Law
# ...                                                 ...
# 4994                           Shrimp Pad Thai For Four
# 4995                      Hot and Crunchy Avocado Fries
# 4996                   Fontina Mac with Squash and Sage
# 4997                  Spicy Jalapeño Sweet Potato Fries
# 4998                                Red Velvet Mug Cake
#
#                                             Ingredients  \
# 0     ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1     ['2 large egg whites', '1 pound new potatoes (...
# 2     ['1 cup evaporated milk', '1 cup whole milk', ...
# 3     ['1 (¾- to 1-pound) round Italian loaf, cut in...
# ...

# %%
# test = df['Bag_Of_Ingredients'][0:5]
# type(test)
# Out:
# pandas.core.series.Series

# %%
# remove_stopwords(test)
# Out:
# Returning list of 461 stopwords
# lb whole chicken tsp kosher salt divided plus more small acorn squash about lb total Tbsp finely chopped sage Tbsp finely chopped rosemary Tbsp unsalted butter melted plus Tbsp room temperature tsp ground allspice Pinch of crushed red pepper flakes Freshly ground black pepper loaf goodquality sturdy white bread torn into pieces about cups medium apples such as Gala or Pink Lady about oz total cored cut into pieces Tbsp extravirgin olive oil small red onion thinly sliced Tbsp apple cider vinegar Tbsp white miso cup allpurpose flour Tbsp unsalted butter room temperature cup dry white wine cups unsalted chicken broth tsp white miso Kosher salt freshly ground pepper
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.13/envs/wots_cookin/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(4293, None, None), slice(None, None, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 df[4293:, :]
#
# ...

# %%
df['Bag_Of_Ingredients']
# Out:
# 5       chamomile tea bags oz reposado tequila oz fres...
# 6       oz Grand Marnier oz Amaro Averna Small pat sal...
# 7       cup granulated sugar tsp ground turmeric oz Am...
# 8       cup assorted dals such as chana dal moong dal ...
# 9       ounce can basic lentil soup like Amys large on...
#                               ...
# 4995    cup water teaspoons prepared tamarind paste pr...
# 4996    cup panko breadcrumbs tablespoons ground flax ...
# 4997    tablespoons shredded Parmesan ounces shell pas...
# 4998    medium peeled sweet potatoes tablespoon cornst...
# 4999    large egg tablespoons vegetable oil teaspoon l...
# Name: Bag_Of_Ingredients, Length: 4994, dtype: object

# %%
df.shape
# Out:
# (4999, 6)

# %%
# Out:
#       index                  Title  \
# 4293   4294  Roasted Poultry Stock
#
#                                             Ingredients  \
# 4293  ['Turkey neck, back, if spatchcocked, and gibl...
#
#                                            Instructions  \
# 4293  Preheat oven to 450°. Divide turkey parts, oni...
#
#                           Image_Name  \
# 4293  roasted-poultry-stock-51255620
#
#                                     Cleaned_Ingredients
# 4293  ['Turkey neck, back, if spatchcocked, and gibl...

# %%
df
# Out:
#                                                   Title  \
# 0     Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                       Crispy Salt and Pepper Potatoes
# 2                           Thanksgiving Mac and Cheese
# 3                    Italian Sausage and Bread Stuffing
# 4                                          Newton's Law
# ...                                                 ...
# 4995                           Shrimp Pad Thai For Four
# 4996                      Hot and Crunchy Avocado Fries
# 4997                   Fontina Mac with Squash and Sage
# 4998                  Spicy Jalapeño Sweet Potato Fries
# 4999                                Red Velvet Mug Cake
#
#                                             Ingredients  \
# 0     ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1     ['2 large egg whites', '1 pound new potatoes (...
# 2     ['1 cup evaporated milk', '1 cup whole milk', ...
# 3     ['1 (¾- to 1-pound) round Italian loaf, cut in...
# ...

# %%
df['Bag_Of_Ingredients'] = df['Bag_Of_Ingredients'].map(remove_stopwords)
# Out:
# Returning list of 461 stopwords
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df['Bag_Of_Ingredients'] = df['Bag_Of_Ingredients'].map(remove_stopwords)
#
# File ~/.pyenv/versions/3.8.13/envs/wots_cookin/lib/python3.8/site-packages/pandas/core/series.py:4237, in Series.map(self, arg, na_action)
#    4162 def map(self, arg, na_action=None) -> Series:
#    4163     """
#    4164     Map values of Series according to an input mapping or function.
#    4165
#    (...)
#    4235     dtype: object
#    4236     """
# -> 4237     new_values = self._map_values(arg, na_action=na_action)
#    4238     return self._constructor(new_values, index=self.index).__finalize__(
#    4239         self, method="map"
#    4240     )
#
# ...

# %%
df
# Out:
#                                                   Title  \
# 0     Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                       Crispy Salt and Pepper Potatoes
# 2                           Thanksgiving Mac and Cheese
# 3                    Italian Sausage and Bread Stuffing
# 4                                          Newton's Law
# ...                                                 ...
# 4995                           Shrimp Pad Thai For Four
# 4996                      Hot and Crunchy Avocado Fries
# 4997                   Fontina Mac with Squash and Sage
# 4998                  Spicy Jalapeño Sweet Potato Fries
# 4999                                Red Velvet Mug Cake
#
#                                             Ingredients  \
# 0     ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1     ['2 large egg whites', '1 pound new potatoes (...
# 2     ['1 cup evaporated milk', '1 cup whole milk', ...
# 3     ['1 (¾- to 1-pound) round Italian loaf, cut in...
# ...

# %%
# # Count of rows containing NA. This doesn't take into account overlapping rows
# pd.DataFrame(df.isna().sum()).sum()[0]
# Out:
# 13

# %%
# # Function to remove punctuation, numbers and weird formatting
# # Takes string and returns string 

# def remove_formatting(ingredient_list):
#     '''function to clean ingredints list'''
#     punctuation = string.punctuation
    
#     # break string into list of individual items
#     ingredient_list = ingredient_list.split("', \'")

#     # iterate through each item in list to remove punctuation and non alpha characters
#     for i in range(len(ingredient_list)):
#         for punc in punctuation:
#             ingredient_list[i] = ingredient_list[i].replace(punc, '')
#         ingredient_list[i] = ''.join(char for char in ingredient_list[i] if char.isalpha() or char == ' ')
#         ingredient_list[i] = ingredient_list[i].strip()
#         ingredient_list[i] = ingredient_list[i].replace('  ', ' ')
#     return ' '. join(ingredient_list)

# %% [markdown]
# ## Data sanity checks

# %%
recipes_df.describe()
# Out:
#          Unnamed: 0
# count  13501.000000
# mean    6750.000000
# std     3897.547327
# min        0.000000
# 25%     3375.000000
# 50%     6750.000000
# 75%    10125.000000
# max    13500.000000

# %%
recipes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13501 entries, 0 to 13500
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           13501 non-null  int64
#  1   Title                13496 non-null  object
#  2   Ingredients          13501 non-null  object
#  3   Instructions         13493 non-null  object
#  4   Image_Name           13501 non-null  object
#  5   Cleaned_Ingredients  13501 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 633.0+ KB

# %%
recipes_df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1           1                    Crispy Salt and Pepper Potatoes
# 2           2                        Thanksgiving Mac and Cheese
# 3           3                 Italian Sausage and Bread Stuffing
# 4           4                                       Newton's Law
#
#                                          Ingredients  \
# 0  ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1  ['2 large egg whites', '1 pound new potatoes (...
# 2  ['1 cup evaporated milk', '1 cup whole milk', ...
# 3  ['1 (¾- to 1-pound) round Italian loaf, cut in...
# 4  ['1 teaspoon dark brown sugar', '1 teaspoon ho...
#
#                                         Instructions  \
# 0  Pat chicken dry with paper towels, season all ...
# 1  Preheat oven to 400°F and line a rimmed baking...
# 2  Place a rack in middle of oven; preheat to 400...
# ...

# %% [markdown]
# ## Checking for nulls and na

# %%
recipes_df.isna().sum()
# Out:
# Unnamed: 0             0
# Title                  5
# Ingredients            0
# Instructions           8
# Image_Name             0
# Cleaned_Ingredients    0
# dtype: int64

# %%
recipes_df[recipes_df["Title"].isna()]
# Out:
#        Unnamed: 0 Title Ingredients Instructions  \
# 11221       11221   NaN          []          NaN
# 12373       12373   NaN          []          NaN
# 12378       12378   NaN          []          NaN
# 12818       12818   NaN          []          NaN
# 12829       12829   NaN          []          NaN
#
#                                               Image_Name Cleaned_Ingredients
# 11221  roasted-game-hens-with-caramelized-root-vegeta...                ['']
# 12373                      chicken-soup-with-rice-232605                ['']
# 12378                           double-lemon-bars-232572                ['']
# 12818  pear-and-frangipane-crostata-with-raspberry-vi...                ['']
# 12829                  hazelnut-shortbread-sticks-231311                ['']

# %%
recipes_df[recipes_df["Instructions"].isna()]
# Out:
#        Unnamed: 0                                           Title  \
# 4293         4293  Broccolini-Cheddar Gratin with Rye Breadcrumbs
# 9636         9636    Smoked Salmon with Egg Salad and Green beans
# 10356       10356                                     Royal Icing
# 11221       11221                                             NaN
# 12373       12373                                             NaN
# 12378       12378                                             NaN
# 12818       12818                                             NaN
# 12829       12829                                             NaN
#
#                                              Ingredients Instructions  \
# 4293   ['1/4 loaf seeded rye bread, torn into 1" piec...          NaN
# 9636                                                  []          NaN
# 10356  ['Using electric mixer, beat 3 1/4 cups powder...          NaN
# 11221                                                 []          NaN
# ...

# %% [markdown]
# ## Cleaning the data

# %%
# from nltk.corpus import stopwords 
# stopwords = set(stopwords.words('english')) 
# custom_stopwords = load_custom_stopwords()
# full_stopwords = stopwords | set(custom_stopwords)
# pd.DataFrame(full_stopwords).to_csv('full_stopwords.csv')
# Out:
# {'a',
#  'about',
#  'above',
#  'according',
#  'additional',
#  'after',
#  'again',
#  'against',
#  'agricole',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'andor',
#  'any',
#  'approximately',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'assorted ',
#  'at',
#  'attached',
#  'bag',
#  'be',
#  'beaten',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'bias',
#  'big',
#  'bitesize',
#  'blackstrap',
#  'blanched',
#  'blend',
#  'boiling',
#  'bonein',
#  'boneless',
#  'both',
#  'bowl',
#  'brushing',
#  'bunch',
#  'bunches',
#  'but',
#  'by',
#  'can',
#  'cans',
#  'chilled',
#  'choice',
#  'chopped',
#  'chunks',
#  'clean',
#  'cleaned',
#  'cm',
#  'coarse',
#  'coarsely',
#  'cold',
#  'confectioners',
#  'cooked',
#  'cooled',
#  'cored',
#  'couldn',
#  "couldn't",
#  'countrystyle',
#  'cracked',
#  'creole',
#  'crosswise',
#  'crumbled',
#  'crushed',
#  'crystal',
#  'cubed',
#  'cubes',
#  'cup',
#  'cupg',
#  'cups',
# ...

# %%
# full_stopwords = list(pd.read_csv("full_stopwords.csv")['0'])
# print(f'Returning {len(full_stopwords)} stopwords')
# Out:
# Returning 461 stopwords

# %%
test_list = ['chicken', 'ball', 'am', 'head', 'ml', 'cups', 'rosemary']

# %%
df
# Out:
#                                                   Title  \
# 0     Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                       Crispy Salt and Pepper Potatoes
# 2                           Thanksgiving Mac and Cheese
# 3                    Italian Sausage and Bread Stuffing
# 4                                          Newton's Law
# ...                                                 ...
# 4995                           Shrimp Pad Thai For Four
# 4996                      Hot and Crunchy Avocado Fries
# 4997                   Fontina Mac with Squash and Sage
# 4998                  Spicy Jalapeño Sweet Potato Fries
# 4999                                Red Velvet Mug Cake
#
#                                             Ingredients  \
# 0     ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1     ['2 large egg whites', '1 pound new potatoes (...
# 2     ['1 cup evaporated milk', '1 cup whole milk', ...
# 3     ['1 (¾- to 1-pound) round Italian loaf, cut in...
# ...

# %%
remove_stopwords(df['Cleaned_Ingredients'])
# Out:
# Returning list of 461 stopwords
# Stopwords loaded
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.13/envs/wots_cookin/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 4293
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['Bag_Of_Ingredients'] = df['Cleaned_Ingredients'].map(remove_stopwords)
# Out:
# Returning list of 461 stopwords
# Stopwords loaded
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 df['Bag_Of_Ingredients'] = df['Cleaned_Ingredients'].map(remove_stopwords)
#
# File ~/.pyenv/versions/3.8.13/envs/wots_cookin/lib/python3.8/site-packages/pandas/core/series.py:4237, in Series.map(self, arg, na_action)
#    4162 def map(self, arg, na_action=None) -> Series:
#    4163     """
#    4164     Map values of Series according to an input mapping or function.
#    4165
#    (...)
#    4235     dtype: object
#    4236     """
# -> 4237     new_values = self._map_values(arg, na_action=na_action)
#    4238     return self._constructor(new_values, index=self.index).__finalize__(
#    4239         self, method="map"
#    4240     )
#
# ...

# %% [markdown]
# ## Bag of Word and Stop Words

# %%
# Setting bag of words scope - first 2000 as a panda series

bag_of_ingredients = recipes_df["Clean2"][:2_000]

# %%
# Removing regular stopwords

stop_words = set(stopwords.words('english')) 

for i in range(0, len(bag_of_ingredients)):
    word_tokens = word_tokenize(bag_of_ingredients[i])
    word_tokens = [w.lower() for w in word_tokens]
    full_stop_words = stop_words | set(custom_stopwords)
    bag_of_ingredients[i] = [w for w in word_tokens if not w in full_stop_words]

# Converting list to string
bag_of_ingredients = bag_of_ingredients.map(' '.join).copy()

# %%
#Creating the bag of words dataframe

vectorizer = CountVectorizer()

X = vectorizer.fit_transform(bag_of_ingredients)

bag_of_ingredients_df = pd.DataFrame(X.toarray(),columns = vectorizer.get_feature_names_out())

# %%
#Doing a count of the bag of words to identify custom stop words
#Denise is doing n00: n50 (Denise up to 850)

bag_of_ingredients_df.sum().sort_values(ascending=False)[0:50] # Starting with the first 50 rows
# Out:
# oil            1515
# ground         1271
# pepper         1156
# fresh           965
# olive           902
# garlic          822
# black           715
# red             701
# butter          660
# juice           653
# leaves          650
# lemon           647
# extravirgin     616
# cloves          564
# white           517
# vinegar         495
# seeds           494
# flour           405
# powder          394
# onion           393
# vegetable       387
# sauce           367
# cream           337
# lime            331
# rice            315
# dried           310
# chicken         309
# wine            295
# allpurpose      293
# eggs            283
# green           281
# vanilla         269
# milk            259
# coconut         258
# ginger          255
# brown           242
# cilantro        237
# baking          235
# egg             231
# cheese          228
# parsley         225
# tomatoes        225
# dry             220
# extract         212
# honey           210
# ...

# %%
bag_of_ingredients = np.array(bag_of_ingredients)

# %%
train_sentences = bag_of_ingredients[:1800]
test_sentences = bag_of_ingredients[1800:]

# %%
train_sentences[0]
# Out:
# 'chicken acorn squash sage rosemary butter ground allspice red pepper ground black pepper loaf sturdy white bread apples gala pink lady extravirgin olive oil red onion apple cider vinegar white miso allpurpose flour butter dry white wine chicken broth white miso ground pepper'

# %%
for sentence in train_sentences:
    print(sentence)
#     for ingredient in range(0, len(sentence)):
#         print(ingredient)
#         ingredients = word_tokenize(ingredient[i])
# Out:
# chicken acorn squash sage rosemary butter ground allspice red pepper ground black pepper loaf sturdy white bread apples gala pink lady extravirgin olive oil red onion apple cider vinegar white miso allpurpose flour butter dry white wine chicken broth white miso ground pepper
# egg whites new potatoes ground black pepper rosemary thyme parsley
# evaporated milk milk garlic powder onion powder smoked paprika ground black pepper extrasharp cheddar fullfat cream cheese elbow macaroni
# round italian loaf olive oil sweet italian sausage casings stick butter onions celery ribs garlic cloves eggs heavy cream turkey giblet reducedsodium chicken broth parmigianoreggiano flatleaf parsley qt shallow ceramic glass baking dish
# dark brown bourbon fresh lemon juice apple butter orange ground cinnamon
# chamomile tea bags tequila fresh lemon juice agave nectar
# grand marnier amaro averna pat butter apple cider fresh lemon juice sweetness cider ground pink peppercorns lemon wheels
# ...

# %%
word_tokens
# Out:
# ['allpurpose',
#  'flour',
#  'stick',
#  'butter',
#  'granulated',
#  'light',
#  'brown',
#  'milk',
#  'vanilla',
#  'extract',
#  'chocolate',
#  'chips',
#  'creamfilled',
#  'chocolate',
#  'sandwich',
#  'cookies',
#  'oreos',
#  'vegetable',
#  'oil',
#  'cocoa',
#  'powder',
#  'marshmallows',
#  'almonds',
#  'chocolate',
#  'chips',
#  'vegetable',
#  'oil',
#  'quickcooking',
#  'oats',
#  'walnuts',
#  'raisins',
#  'vegetable',
#  'oil',
#  'ground',
#  'cinnamon',
#  'smooth',
#  'peanut',
#  'butter',
#  'peanut',
#  'butter',
#  'ths',
#  'shell',
#  'peanut',
#  'butter',
#  'chocolate',
#  'candies',
#  'reeses']
